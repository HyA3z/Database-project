# %%
from faker import Faker

fake = Faker()

# Starting IDs for each table
patient_id = 30
doctor_id = 30
appointment_id = 30
record_id = 30
department_id = 30
staff_id = 30
admission_id = 30
room_id = 30
bed_id = 30
medication_id = 30
prescription_id = 30
bill_id = 30
payment_id = 30

# Generate fake data for the Patients table
patients_data = []
for _ in range(1000):
    patients_data.append({
        'PatientID': patient_id,
        'FirstName': fake.first_name(),
        'LastName': fake.last_name(),
        'Gender': fake.random_element(elements=('Male', 'Female')),
        'DateOfBirth': fake.date_of_birth(minimum_age=18, maximum_age=90),
        'Address': fake.address(),
        'PhoneNumber': fake.phone_number()[:20]
    })
    patient_id += 1

# Generate fake data for the Doctors table
doctors_data = []
for _ in range(1000):
    doctors_data.append({
        'DoctorID': doctor_id,
        'FirstName': fake.first_name(),
        'LastName': fake.last_name(),
        'Gender': fake.random_element(elements=('Male', 'Female')),
        'DateOfBirth': fake.date_of_birth(minimum_age=30, maximum_age=70),
        'Address': fake.address(),
        'PhoneNumber': fake.phone_number()[:20],
        'Specialization': fake.random_element(elements=('Cardiology', 'Dermatology', 'Neurology', 'Pediatrics'))
    })
    doctor_id += 1

# Generate fake data for the Appointments table
appointments_data = []
for _ in range(1000):
    appointments_data.append({
        'AppointmentID': appointment_id,
        'PatientID': fake.random_int(min=30, max=patient_id-1),
        'DoctorID': fake.random_int(min=30, max=doctor_id-1),
        'AppointmentDate': fake.date_between(start_date='-1y', end_date='today'),
        'AppointmentTime': fake.time(pattern='%H:%M')
    })
    appointment_id += 1

# Generate fake data for the MedicalRecords table
medical_records_data = []
for _ in range(1000):
    diagnosis = fake.sentence(nb_words=6)
    treatment = fake.paragraph(nb_sentences=3)[:200]  # Truncate treatment to a maximum of 200 characters
    medical_records_data.append({
        'RecordID': record_id,
        'PatientID': fake.random_int(min=30, max=patient_id - 1),
        'DoctorID': fake.random_int(min=30, max=doctor_id - 1),
        'RecordDate': fake.date_between(start_date='-2y', end_date='today'),
        'Diagnosis': diagnosis,
        'Treatment': treatment
    })
    record_id += 1


# Generate fake data for the Departments table
departments_data = []
for _ in range(1000):
    departments_data.append({
        'DepartmentID': department_id,
        'DepartmentName': fake.random_element(elements=('Cardiology', 'Dermatology', 'Neurology', 'Pediatrics'))
    })
    department_id += 1

# Generate fake data for the Staff table
staff_data = []
for _ in range(1000):
    phone_number = fake.phone_number()[:20]  # Truncate phone number to a maximum of 20 characters
    staff_data.append({
        'StaffID': staff_id,
        'DepartmentID': fake.random_int(min=30, max=department_id-1),
        'FirstName': fake.first_name(),
        'LastName': fake.last_name(),
        'Gender': fake.random_element(elements=('Male', 'Female')),
        'DateOfBirth': fake.date_of_birth(minimum_age=25, maximum_age=60),
        'Address': fake.address(),
        'PhoneNumber': phone_number
    })
    staff_id += 1


# Generate fake data for the Admissions table
admissions_data = []
for _ in range(1000):
    admissions_data.append({
        'AdmissionID': admission_id,
        'PatientID': fake.random_int(min=30, max=patient_id-1),
        'AdmissionDate': fake.date_between(start_date='-2y', end_date='today'),
        'DischargeDate': fake.date_between(start_date='-1y', end_date='today')
    })
    admission_id += 1

# Generate fake data for the Rooms table
rooms_data = []
for _ in range(1000):
    rooms_data.append({
        'RoomID': room_id,
        'RoomNumber': fake.random_int(min=100, max=999),
        'RoomType': fake.random_element(elements=('Private', 'Shared')),
        'DepartmentID': fake.random_int(min=30, max=department_id-1)
    })
    room_id += 1

# Generate fake data for the Beds table
beds_data = []
for _ in range(1000):
    beds_data.append({
        'BedID': bed_id,
        'RoomID': fake.random_int(min=30, max=room_id-1),
        'BedNumber': fake.random_int(min=1, max=10)
    })
    bed_id += 1

# Generate fake data for the Medications table
medications_data = []
for _ in range(1000):
    medications_data.append({
        'MedicationID': medication_id,
        'MedicationName': fake.word(),
        'MedicationDescription': fake.sentence(nb_words=6)
    })
    medication_id += 1

# Generate fake data for the Prescriptions table
prescriptions_data = []
for _ in range(1000):
    prescriptions_data.append({
        'PrescriptionID': prescription_id,
        'PatientID': fake.random_int(min=30, max=patient_id-1),
        'DoctorID': fake.random_int(min=30, max=doctor_id-1),
        'MedicationID': fake.random_int(min=30, max=medication_id-1),
        'PrescriptionDate': fake.date_between(start_date='-1y', end_date='today'),
        'Dosage': fake.random_element(elements=('1 tablet', '2 tablets', '1 capsule', '1 teaspoon'))
    })
    prescription_id += 1

# Generate fake data for the Billing table
billing_data = []
for _ in range(1000):
    billing_data.append({
        'BillID': bill_id,
        'PatientID': fake.random_int(min=30, max=patient_id-1),
        'BillDate': fake.date_between(start_date='-1y', end_date='today'),
        'TotalCost': round(fake.random.uniform(100, 1000), 2)
    })
    bill_id += 1

# Generate fake data for the Payments table
payments_data = []
for _ in range(1000):
    payments_data.append({
        'PaymentID': payment_id,
        'PatientID': fake.random_int(min=30, max=patient_id-1),
        'PaymentDate': fake.date_between(start_date='-1y', end_date='today'),
        'PaymentAmount': round(fake.random.uniform(50, 500), 2)
    })
    payment_id += 1

# Print the generated data
print



# Print the generated data
print("Patients_data:", patients_data)
print("Doctors_data:", doctors_data)
print("Appointments_data:", appointments_data)
print("MedicalRecords_data:", medical_records_data)
print("Departments_data:", departments_data)
print("Staff_data:", staff_data)
print("Admissions_data:", admissions_data)
print("Rooms_data:", rooms_data)
print("Beds_data:", beds_data)
print("Medications_data:", medications_data)
print("Prescriptions_data:", prescriptions_data)
print("Billing_data:", billing_data)
print("Payments_data:", payments_data)
# Out:
# Patients_data: [{'PatientID': 30, 'FirstName': 'Heather', 'LastName': 'Gutierrez', 'Gender': 'Male', 'DateOfBirth': datetime.date(1955, 9, 26), 'Address': '75885 Brian Village Suite 500\nNew Nicolemouth, TX 96027', 'PhoneNumber': '(710)275-4398x997'}, {'PatientID': 31, 'FirstName': 'Kathryn', 'LastName': 'Jones', 'Gender': 'Female', 'DateOfBirth': datetime.date(1941, 1, 10), 'Address': '7976 Jesus Extensions\nJohnsonfurt, HI 21610', 'PhoneNumber': '001-035-863-7460x297'}, {'PatientID': 32, 'FirstName': 'John', 'LastName': 'Goodman', 'Gender': 'Male', 'DateOfBirth': datetime.date(1934, 4, 13), 'Address': 'USCGC Payne\nFPO AP 89809', 'PhoneNumber': '+1-774-723-5308'}, {'PatientID': 33, 'FirstName': 'Rachel', 'LastName': 'Ryan', 'Gender': 'Female', 'DateOfBirth': datetime.date(1952, 10, 30), 'Address': '2531 Reid Spur\nDavidside, PW 74918', 'PhoneNumber': '+1-892-313-2737'}, {'PatientID': 34, 'FirstName': 'Kimberly', 'LastName': 'Walker', 'Gender': 'Female', 'DateOfBirth': datetime.date(1945, 5, 24), 'Address': '8968 Hickman Wall\nLake Johnmouth, ND 51320', 'PhoneNumber': '(174)956-5876x472'}, {'PatientID': 35, 'FirstName': 'Crystal', 'LastName': 'Owen', 'Gender': 'Male', 'DateOfBirth': datetime.date(1965, 8, 24), 'Address': '16429 Logan Turnpike Suite 441\nDanielberg, MO 90638', 'PhoneNumber': '579-812-8080x4431'}, {'PatientID': 36, 'FirstName': 'Rebecca', 'LastName': 'Cook', 'Gender': 'Female', 'DateOfBirth': datetime.date(1990, 2, 13), 'Address': '103 Turner Mews Apt. 219\nWest Michael, WA 22956', 'PhoneNumber': '001-645-157-6736x527'}, {'PatientID': 37, 'FirstName': 'Christopher', 'LastName': 'Daniel', 'Gender': 'Female', 'DateOfBirth': datetime.date(1999, 7, 16), 'Address': '8880 Andrew Camp\nLindaport, CO 35894', 'PhoneNumber': '001-286-885-1898x954'}, {'PatientID': 38, 'FirstName': 'Sean', 'LastName': 'Lara', 'Gender': 'Male', 'DateOfBirth': datetime.date(1966, 3, 31), 'Address': '037 James Crossing\nNorth Donna, GA 67253', 'PhoneNumber': '(716)227-1300'}, {'PatientID': 39, 'FirstName': 'Nicole', 'LastName': 'Perez', 'Gender': 'Male', 'DateOfBirth': datetime.date(1983, 6, 9), 'Address': '28722 Victoria Fort Suite 282\nNorth Brittanymouth, AS 26488', 'PhoneNumber': '5271222152'}, {'PatientID': 40, 'FirstName': 'Jose', 'LastName': 'Williams', 'Gender': 'Male', 'DateOfBirth': datetime.date(1965, 5, 2), 'Address': 'USS Clark\nFPO AE 59663', 'PhoneNumber': '+1-846-271-8019x372'}, {'PatientID': 41, 'FirstName': 'Amanda', 'LastName': 'Powell', 'Gender': 'Female', 'DateOfBirth': datetime.date(1943, 3, 11), 'Address': '5481 Alvarez Parkways Apt. 238\nEast Calebmouth, NJ 56433', 'PhoneNumber': '1655091846'}, {'PatientID': 42, 'FirstName': 'Matthew', 'LastName': 'Harrison', 'Gender': 'Male', 'DateOfBirth': datetime.date(1962, 6, 27), 'Address': '687 Leonard Heights\nTerryfort, MN 61429', 'PhoneNumber': '(354)676-4358'}, {'PatientID': 43, 'FirstName': 'Joshua', 'LastName': 'Thomas', 'Gender': 'Female', 'DateOfBirth': datetime.date(2005, 1, 10), 'Address': '922 Robinson Manor Suite 752\nHuynhside, MN 81120', 'PhoneNumber': '090.654.7236'}, {'PatientID': 44, 'FirstName': 'Seth', 'LastName': 'Tyler', 'Gender': 'Female', 'DateOfBirth': datetime.date(1940, 2, 15), 'Address': '49170 Espinoza Overpass\nEast Christopherton, NJ 36068', 'PhoneNumber': '754.933.5924x4262'}, {'PatientID': 45, 'FirstName': 'Ian', 'LastName': 'Ali', 'Gender': 'Male', 'DateOfBirth': datetime.date(1964, 9, 11), 'Address': '6747 Peter Hollow Apt. 748\nNorth Victoria, RI 12912', 'PhoneNumber': '308-604-1528x276'}, {'PatientID': 46, 'FirstName': 'Brian', 'LastName': 'Delacruz', 'Gender': 'Male', 'DateOfBirth': datetime.date(1998, 11, 24), 'Address': '973 Anderson River\nSouth Lisa, KS 13329', 'PhoneNumber': '9744086543'}, {'PatientID': 47, 'FirstName': 'Jill', 'LastName': 'Morris', 'Gender': 'Female', 'DateOfBirth': datetime.date(1956, 3, 10), 'Address': '6259 Robert Forest\nPort Cindy, WV 66588', 'PhoneNumber': '323.190.1802'}, {'PatientID': 48, 'FirstName': 'Molly', ' ...
# Doctors_data: [{'DoctorID': 30, 'FirstName': 'Tina', 'LastName': 'Davis', 'Gender': 'Male', 'DateOfBirth': datetime.date(1976, 2, 1), 'Address': '5571 Regina Rest\nThomasview, MS 60836', 'PhoneNumber': '507-682-2083', 'Specialization': 'Neurology'}, {'DoctorID': 31, 'FirstName': 'Austin', 'LastName': 'Becker', 'Gender': 'Female', 'DateOfBirth': datetime.date(1967, 10, 1), 'Address': '307 Hughes Trace Suite 866\nRamireztown, NE 74412', 'PhoneNumber': '(488)951-3355', 'Specialization': 'Pediatrics'}, {'DoctorID': 32, 'FirstName': 'Katherine', 'LastName': 'Brewer', 'Gender': 'Female', 'DateOfBirth': datetime.date(1974, 3, 30), 'Address': '30176 Richard Roads\nSwansonmouth, CO 91525', 'PhoneNumber': '+1-506-772-2777x5796', 'Specialization': 'Neurology'}, {'DoctorID': 33, 'FirstName': 'Amanda', 'LastName': 'Mcdaniel', 'Gender': 'Female', 'DateOfBirth': datetime.date(1979, 5, 5), 'Address': '6818 Moran Ports\nHarrisstad, NY 41015', 'PhoneNumber': '243.384.9407', 'Specialization': 'Dermatology'}, {'DoctorID': 34, 'FirstName': 'Joel', 'LastName': 'Green', 'Gender': 'Female', 'DateOfBirth': datetime.date(1966, 10, 9), 'Address': '86517 Yang Track\nWest Phillip, OR 32142', 'PhoneNumber': '+1-348-482-6830x660', 'Specialization': 'Dermatology'}, {'DoctorID': 35, 'FirstName': 'Ariel', 'LastName': 'Moore', 'Gender': 'Female', 'DateOfBirth': datetime.date(1960, 9, 9), 'Address': '772 Byrd Burg\nWest Victorfort, AR 98205', 'PhoneNumber': '+1-295-665-1218x5273', 'Specialization': 'Pediatrics'}, {'DoctorID': 36, 'FirstName': 'Edward', 'LastName': 'Johnson', 'Gender': 'Male', 'DateOfBirth': datetime.date(1982, 3, 17), 'Address': '80205 Walter Islands Apt. 412\nNew Yeseniachester, VA 13647', 'PhoneNumber': '041-911-5952', 'Specialization': 'Pediatrics'}, {'DoctorID': 37, 'FirstName': 'Connie', 'LastName': 'Garrett', 'Gender': 'Female', 'DateOfBirth': datetime.date(1968, 5, 31), 'Address': '9501 Amanda Lakes Apt. 125\nFitzgeraldfort, WI 80677', 'PhoneNumber': '+1-580-304-0553x180', 'Specialization': 'Dermatology'}, {'DoctorID': 38, 'FirstName': 'Lindsey', 'LastName': 'Walters', 'Gender': 'Male', 'DateOfBirth': datetime.date(1973, 6, 9), 'Address': '20046 Miller Tunnel\nLake Brianna, OH 46288', 'PhoneNumber': '0861014975', 'Specialization': 'Cardiology'}, {'DoctorID': 39, 'FirstName': 'Emily', 'LastName': 'Jones', 'Gender': 'Male', 'DateOfBirth': datetime.date(1992, 2, 2), 'Address': '62444 Robert Pines\nJonesborough, OH 37561', 'PhoneNumber': '+1-850-480-2445x8560', 'Specialization': 'Neurology'}, {'DoctorID': 40, 'FirstName': 'Donald', 'LastName': 'Graham', 'Gender': 'Male', 'DateOfBirth': datetime.date(1953, 12, 23), 'Address': '568 Jamie Mill Suite 668\nAndrewmouth, CO 64730', 'PhoneNumber': '+1-601-431-5034x3205', 'Specialization': 'Dermatology'}, {'DoctorID': 41, 'FirstName': 'Amber', 'LastName': 'Roman', 'Gender': 'Female', 'DateOfBirth': datetime.date(1954, 12, 21), 'Address': '38627 Booker Parkway\nJacquelinetown, MD 26777', 'PhoneNumber': '+1-519-462-1343', 'Specialization': 'Pediatrics'}, {'DoctorID': 42, 'FirstName': 'Scott', 'LastName': 'Phillips', 'Gender': 'Female', 'DateOfBirth': datetime.date(1983, 6, 15), 'Address': '13398 Henderson Path\nNicolasshire, VT 95545', 'PhoneNumber': '486-117-3729x474', 'Specialization': 'Dermatology'}, {'DoctorID': 43, 'FirstName': 'Kelly', 'LastName': 'House', 'Gender': 'Male', 'DateOfBirth': datetime.date(1967, 11, 23), 'Address': '0357 Scott Island\nWestville, ND 87561', 'PhoneNumber': '+1-101-226-2249', 'Specialization': 'Pediatrics'}, {'DoctorID': 44, 'FirstName': 'Karen', 'LastName': 'Richards', 'Gender': 'Male', 'DateOfBirth': datetime.date(1980, 5, 23), 'Address': '12907 Miller Throughway Apt. 375\nEast Brittany, SD 03123', 'PhoneNumber': '+1-029-467-0242x349', 'Specialization': 'Pediatrics'}, {'DoctorID': 45, 'FirstName': 'Brian', 'LastName': 'Wilson', 'Gender': 'Female', 'DateOfBirth': datetime.date(1990, 5, 6), 'Address': '3550 Collins Parkway\nLake Sharonside, DC 20090', 'PhoneNumber': '001 ...
# Appointments_data: [{'AppointmentID': 30, 'PatientID': 647, 'DoctorID': 1012, 'AppointmentDate': datetime.date(2022, 12, 27), 'AppointmentTime': '04:05'}, {'AppointmentID': 31, 'PatientID': 675, 'DoctorID': 85, 'AppointmentDate': datetime.date(2022, 6, 24), 'AppointmentTime': '02:52'}, {'AppointmentID': 32, 'PatientID': 908, 'DoctorID': 81, 'AppointmentDate': datetime.date(2022, 8, 2), 'AppointmentTime': '16:29'}, {'AppointmentID': 33, 'PatientID': 153, 'DoctorID': 939, 'AppointmentDate': datetime.date(2022, 6, 16), 'AppointmentTime': '18:19'}, {'AppointmentID': 34, 'PatientID': 729, 'DoctorID': 791, 'AppointmentDate': datetime.date(2022, 7, 15), 'AppointmentTime': '17:54'}, {'AppointmentID': 35, 'PatientID': 326, 'DoctorID': 677, 'AppointmentDate': datetime.date(2023, 2, 2), 'AppointmentTime': '11:18'}, {'AppointmentID': 36, 'PatientID': 559, 'DoctorID': 308, 'AppointmentDate': datetime.date(2023, 3, 10), 'AppointmentTime': '15:07'}, {'AppointmentID': 37, 'PatientID': 407, 'DoctorID': 911, 'AppointmentDate': datetime.date(2023, 1, 12), 'AppointmentTime': '12:24'}, {'AppointmentID': 38, 'PatientID': 606, 'DoctorID': 535, 'AppointmentDate': datetime.date(2022, 6, 7), 'AppointmentTime': '18:25'}, {'AppointmentID': 39, 'PatientID': 750, 'DoctorID': 365, 'AppointmentDate': datetime.date(2022, 8, 9), 'AppointmentTime': '01:40'}, {'AppointmentID': 40, 'PatientID': 235, 'DoctorID': 790, 'AppointmentDate': datetime.date(2022, 12, 20), 'AppointmentTime': '17:10'}, {'AppointmentID': 41, 'PatientID': 945, 'DoctorID': 895, 'AppointmentDate': datetime.date(2022, 12, 28), 'AppointmentTime': '22:01'}, {'AppointmentID': 42, 'PatientID': 218, 'DoctorID': 72, 'AppointmentDate': datetime.date(2023, 4, 8), 'AppointmentTime': '12:05'}, {'AppointmentID': 43, 'PatientID': 82, 'DoctorID': 931, 'AppointmentDate': datetime.date(2022, 12, 15), 'AppointmentTime': '07:17'}, {'AppointmentID': 44, 'PatientID': 214, 'DoctorID': 211, 'AppointmentDate': datetime.date(2023, 5, 3), 'AppointmentTime': '11:04'}, {'AppointmentID': 45, 'PatientID': 87, 'DoctorID': 496, 'AppointmentDate': datetime.date(2022, 11, 19), 'AppointmentTime': '02:41'}, {'AppointmentID': 46, 'PatientID': 671, 'DoctorID': 657, 'AppointmentDate': datetime.date(2023, 2, 26), 'AppointmentTime': '05:47'}, {'AppointmentID': 47, 'PatientID': 1013, 'DoctorID': 921, 'AppointmentDate': datetime.date(2023, 4, 11), 'AppointmentTime': '03:28'}, {'AppointmentID': 48, 'PatientID': 937, 'DoctorID': 300, 'AppointmentDate': datetime.date(2022, 10, 6), 'AppointmentTime': '09:25'}, {'AppointmentID': 49, 'PatientID': 691, 'DoctorID': 89, 'AppointmentDate': datetime.date(2023, 1, 14), 'AppointmentTime': '18:53'}, {'AppointmentID': 50, 'PatientID': 887, 'DoctorID': 116, 'AppointmentDate': datetime.date(2023, 2, 1), 'AppointmentTime': '07:36'}, {'AppointmentID': 51, 'PatientID': 496, 'DoctorID': 57, 'AppointmentDate': datetime.date(2022, 7, 7), 'AppointmentTime': '03:03'}, {'AppointmentID': 52, 'PatientID': 246, 'DoctorID': 347, 'AppointmentDate': datetime.date(2022, 12, 19), 'AppointmentTime': '14:29'}, {'AppointmentID': 53, 'PatientID': 685, 'DoctorID': 265, 'AppointmentDate': datetime.date(2023, 4, 22), 'AppointmentTime': '20:02'}, {'AppointmentID': 54, 'PatientID': 587, 'DoctorID': 389, 'AppointmentDate': datetime.date(2023, 4, 26), 'AppointmentTime': '21:07'}, {'AppointmentID': 55, 'PatientID': 206, 'DoctorID': 527, 'AppointmentDate': datetime.date(2022, 7, 25), 'AppointmentTime': '16:28'}, {'AppointmentID': 56, 'PatientID': 862, 'DoctorID': 631, 'AppointmentDate': datetime.date(2023, 1, 8), 'AppointmentTime': '03:23'}, {'AppointmentID': 57, 'PatientID': 149, 'DoctorID': 355, 'AppointmentDate': datetime.date(2022, 6, 25), 'AppointmentTime': '16:32'}, {'AppointmentID': 58, 'PatientID': 960, 'DoctorID': 583, 'AppointmentDate': datetime.date(2022, 9, 5), 'AppointmentTime': '13:46'}, {'AppointmentID': 59, 'PatientID': 365, 'DoctorID': 655, 'AppointmentDate': datetime.date(2023, 4, 15), 'AppointmentTime': '08:27'}, ...
# MedicalRecords_data: [{'RecordID': 30, 'PatientID': 744, 'DoctorID': 673, 'RecordDate': datetime.date(2021, 12, 30), 'Diagnosis': 'Past accept report agent character clear garden born.', 'Treatment': 'Represent low history put piece. Year public rule will it dark inside.'}, {'RecordID': 31, 'PatientID': 413, 'DoctorID': 969, 'RecordDate': datetime.date(2021, 10, 4), 'Diagnosis': 'Research if window discuss sea including dog network.', 'Treatment': 'Option continue cut relate people wonder. Floor be them piece election single certain.'}, {'RecordID': 32, 'PatientID': 74, 'DoctorID': 726, 'RecordDate': datetime.date(2023, 1, 3), 'Diagnosis': 'Your culture bag senior.', 'Treatment': 'Personal couple not drug laugh carry sign. Remember long we continue occur few road. Inside treat be light where however. Security network choice national fight own people.'}, {'RecordID': 33, 'PatientID': 790, 'DoctorID': 311, 'RecordDate': datetime.date(2023, 5, 4), 'Diagnosis': 'Western every cold race special beyond available.', 'Treatment': 'Laugh reflect suffer open. Many herself minute physical.'}, {'RecordID': 34, 'PatientID': 73, 'DoctorID': 773, 'RecordDate': datetime.date(2021, 9, 28), 'Diagnosis': 'Good less evidence attack because people.', 'Treatment': 'Range then site sea child allow responsibility. Office happy rest record.'}, {'RecordID': 35, 'PatientID': 943, 'DoctorID': 393, 'RecordDate': datetime.date(2022, 9, 2), 'Diagnosis': 'Strong late better civil middle.', 'Treatment': 'Best capital provide its quality. Total nation quite pick. Decade hair stand cell.'}, {'RecordID': 36, 'PatientID': 994, 'DoctorID': 835, 'RecordDate': datetime.date(2021, 10, 4), 'Diagnosis': 'Compare huge window sense stay standard.', 'Treatment': 'Back brother better perform ask truth financial. Quite every purpose role number will happy.'}, {'RecordID': 37, 'PatientID': 796, 'DoctorID': 187, 'RecordDate': datetime.date(2023, 1, 24), 'Diagnosis': 'Me believe stuff plant you.', 'Treatment': 'Now night kitchen stay become campaign stage. We statement party.'}, {'RecordID': 38, 'PatientID': 516, 'DoctorID': 464, 'RecordDate': datetime.date(2022, 9, 20), 'Diagnosis': 'Mother heavy then even audience pattern.', 'Treatment': 'Owner two fight free TV understand team. Money onto war give body officer consider.'}, {'RecordID': 39, 'PatientID': 896, 'DoctorID': 728, 'RecordDate': datetime.date(2023, 1, 28), 'Diagnosis': 'When will kind among.', 'Treatment': 'Fall piece worry particular seven bar. Include add letter he own form stay team.'}, {'RecordID': 40, 'PatientID': 590, 'DoctorID': 517, 'RecordDate': datetime.date(2022, 2, 27), 'Diagnosis': 'Glass form newspaper political.', 'Treatment': 'Customer source lose during eight. Dinner without all young.'}, {'RecordID': 41, 'PatientID': 74, 'DoctorID': 835, 'RecordDate': datetime.date(2022, 12, 26), 'Diagnosis': 'Risk if happy break often who.', 'Treatment': 'Follow drug with nor rock woman region. Listen their boy ask wonder American before. Miss lot arm onto I decade some.'}, {'RecordID': 42, 'PatientID': 167, 'DoctorID': 614, 'RecordDate': datetime.date(2023, 5, 10), 'Diagnosis': 'Better guy within off.', 'Treatment': 'Main student energy. Just around laugh law check church. Quickly cover economic treatment.'}, {'RecordID': 43, 'PatientID': 875, 'DoctorID': 659, 'RecordDate': datetime.date(2022, 7, 12), 'Diagnosis': 'Democratic capital whether add.', 'Treatment': 'Instead offer field debate the issue speech evidence.'}, {'RecordID': 44, 'PatientID': 501, 'DoctorID': 470, 'RecordDate': datetime.date(2022, 9, 24), 'Diagnosis': 'Pm participant work enough.', 'Treatment': 'Entire charge scene model a third perhaps. Actually Republican guy skill world.'}, {'RecordID': 45, 'PatientID': 511, 'DoctorID': 158, 'RecordDate': datetime.date(2022, 7, 2), 'Diagnosis': 'Mean blood present although rest wrong thought.', 'Treatment': 'Involve guy list prepare. Road us station teach. Weight million take.'}, {'RecordID': 46, 'Patien ...
# Departments_data: [{'DepartmentID': 30, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 31, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 32, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 33, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 34, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 35, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 36, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 37, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 38, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 39, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 40, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 41, 'DepartmentName': 'Neurology'}, {'DepartmentID': 42, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 43, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 44, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 45, 'DepartmentName': 'Neurology'}, {'DepartmentID': 46, 'DepartmentName': 'Neurology'}, {'DepartmentID': 47, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 48, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 49, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 50, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 51, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 52, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 53, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 54, 'DepartmentName': 'Neurology'}, {'DepartmentID': 55, 'DepartmentName': 'Neurology'}, {'DepartmentID': 56, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 57, 'DepartmentName': 'Neurology'}, {'DepartmentID': 58, 'DepartmentName': 'Neurology'}, {'DepartmentID': 59, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 60, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 61, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 62, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 63, 'DepartmentName': 'Neurology'}, {'DepartmentID': 64, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 65, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 66, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 67, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 68, 'DepartmentName': 'Neurology'}, {'DepartmentID': 69, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 70, 'DepartmentName': 'Neurology'}, {'DepartmentID': 71, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 72, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 73, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 74, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 75, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 76, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 77, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 78, 'DepartmentName': 'Neurology'}, {'DepartmentID': 79, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 80, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 81, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 82, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 83, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 84, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 85, 'DepartmentName': 'Neurology'}, {'DepartmentID': 86, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 87, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 88, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 89, 'DepartmentName': 'Neurology'}, {'DepartmentID': 90, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 91, 'DepartmentName': 'Neurology'}, {'DepartmentID': 92, 'DepartmentName': 'Neurology'}, {'DepartmentID': 93, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 94, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 95, 'DepartmentName': 'Cardiology'}, {'DepartmentID': 96, 'DepartmentName': 'Neurology'}, {'DepartmentID': 97, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 98, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 99, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 100, 'DepartmentName': 'Neurology'}, {'DepartmentID': 101, 'DepartmentName': 'Pediatrics'}, {'DepartmentID': 102, 'DepartmentName': 'Dermatology'}, {'DepartmentID': 103, 'Departme ...
# Staff_data: [{'StaffID': 30, 'DepartmentID': 748, 'FirstName': 'Michael', 'LastName': 'Holloway', 'Gender': 'Female', 'DateOfBirth': datetime.date(1994, 4, 25), 'Address': 'PSC 7852, Box 0307\nAPO AA 68128', 'PhoneNumber': '(676)799-2804'}, {'StaffID': 31, 'DepartmentID': 941, 'FirstName': 'Richard', 'LastName': 'Dixon', 'Gender': 'Female', 'DateOfBirth': datetime.date(1965, 3, 27), 'Address': '6820 Powell Knolls Suite 414\nNew Michael, NV 79914', 'PhoneNumber': '+1-220-068-1961'}, {'StaffID': 32, 'DepartmentID': 484, 'FirstName': 'Peter', 'LastName': 'Montoya', 'Gender': 'Female', 'DateOfBirth': datetime.date(1969, 10, 25), 'Address': '5745 Silva Throughway Apt. 982\nWest Robin, MI 36577', 'PhoneNumber': '013.877.8968x3496'}, {'StaffID': 33, 'DepartmentID': 585, 'FirstName': 'Fernando', 'LastName': 'Hughes', 'Gender': 'Male', 'DateOfBirth': datetime.date(1969, 6, 28), 'Address': '8796 Melissa Stravenue\nWest Teresa, IN 32383', 'PhoneNumber': '110-920-4559x46808'}, {'StaffID': 34, 'DepartmentID': 533, 'FirstName': 'Kim', 'LastName': 'Glover', 'Gender': 'Female', 'DateOfBirth': datetime.date(1964, 1, 9), 'Address': 'USNS Cannon\nFPO AP 47878', 'PhoneNumber': '+1-303-913-1985x1920'}, {'StaffID': 35, 'DepartmentID': 310, 'FirstName': 'Julie', 'LastName': 'Faulkner', 'Gender': 'Female', 'DateOfBirth': datetime.date(1992, 12, 30), 'Address': '9303 Caitlin Springs Suite 765\nLanestad, ME 43733', 'PhoneNumber': '(357)776-8968'}, {'StaffID': 36, 'DepartmentID': 269, 'FirstName': 'Latoya', 'LastName': 'Kim', 'Gender': 'Female', 'DateOfBirth': datetime.date(1993, 1, 24), 'Address': 'USCGC Rios\nFPO AA 50360', 'PhoneNumber': '001-473-706-4306'}, {'StaffID': 37, 'DepartmentID': 148, 'FirstName': 'Tiffany', 'LastName': 'Nguyen', 'Gender': 'Male', 'DateOfBirth': datetime.date(1992, 5, 19), 'Address': '2140 Bishop Mission\nBarbaramouth, NE 21292', 'PhoneNumber': '+1-402-815-5462'}, {'StaffID': 38, 'DepartmentID': 215, 'FirstName': 'Michelle', 'LastName': 'Clark', 'Gender': 'Female', 'DateOfBirth': datetime.date(1995, 7, 2), 'Address': 'Unit 2306 Box 4480\nDPO AP 00510', 'PhoneNumber': '+1-282-272-0510x9272'}, {'StaffID': 39, 'DepartmentID': 850, 'FirstName': 'Tara', 'LastName': 'Davis', 'Gender': 'Female', 'DateOfBirth': datetime.date(1980, 11, 5), 'Address': '53264 Adams Light Apt. 374\nAmandafurt, AR 19704', 'PhoneNumber': '001-766-083-9987x313'}, {'StaffID': 40, 'DepartmentID': 383, 'FirstName': 'Amy', 'LastName': 'Walker', 'Gender': 'Male', 'DateOfBirth': datetime.date(1994, 5, 26), 'Address': '253 Cunningham Mall\nJohnland, VI 40322', 'PhoneNumber': '329-317-0608'}, {'StaffID': 41, 'DepartmentID': 402, 'FirstName': 'Julia', 'LastName': 'Huffman', 'Gender': 'Female', 'DateOfBirth': datetime.date(1976, 5, 6), 'Address': '037 John Lodge\nLake Carrie, UT 89728', 'PhoneNumber': '471-578-8676x856'}, {'StaffID': 42, 'DepartmentID': 277, 'FirstName': 'Rachel', 'LastName': 'Green', 'Gender': 'Male', 'DateOfBirth': datetime.date(1973, 4, 12), 'Address': '555 Booker Ports\nNew Ryan, TN 55953', 'PhoneNumber': '8816319293'}, {'StaffID': 43, 'DepartmentID': 864, 'FirstName': 'Brandon', 'LastName': 'Fields', 'Gender': 'Male', 'DateOfBirth': datetime.date(1967, 8, 31), 'Address': 'Unit 1026 Box 3272\nDPO AE 30184', 'PhoneNumber': '(408)832-9635'}, {'StaffID': 44, 'DepartmentID': 492, 'FirstName': 'Leslie', 'LastName': 'Garner', 'Gender': 'Male', 'DateOfBirth': datetime.date(1993, 5, 11), 'Address': '620 Jones Vista\nPort Pamelahaven, NJ 54810', 'PhoneNumber': '4077329521'}, {'StaffID': 45, 'DepartmentID': 764, 'FirstName': 'Karen', 'LastName': 'Pennington', 'Gender': 'Male', 'DateOfBirth': datetime.date(1975, 5, 5), 'Address': '1180 Meghan Valley\nSouth Colleen, IL 12194', 'PhoneNumber': '660-934-8952'}, {'StaffID': 46, 'DepartmentID': 571, 'FirstName': 'Andrea', 'LastName': 'Wright', 'Gender': 'Male', 'DateOfBirth': datetime.date(1972, 1, 5), 'Address': '170 Bradley Summit\nCastrochester, WI 35333', 'PhoneNumber': '696.712.5450'}, {'StaffID': 47, 'Dep ...
# Admissions_data: [{'AdmissionID': 30, 'PatientID': 714, 'AdmissionDate': datetime.date(2023, 1, 19), 'DischargeDate': datetime.date(2022, 5, 26)}, {'AdmissionID': 31, 'PatientID': 445, 'AdmissionDate': datetime.date(2021, 9, 19), 'DischargeDate': datetime.date(2022, 10, 7)}, {'AdmissionID': 32, 'PatientID': 887, 'AdmissionDate': datetime.date(2022, 1, 17), 'DischargeDate': datetime.date(2023, 4, 23)}, {'AdmissionID': 33, 'PatientID': 265, 'AdmissionDate': datetime.date(2022, 12, 20), 'DischargeDate': datetime.date(2023, 3, 27)}, {'AdmissionID': 34, 'PatientID': 782, 'AdmissionDate': datetime.date(2021, 8, 13), 'DischargeDate': datetime.date(2022, 5, 27)}, {'AdmissionID': 35, 'PatientID': 199, 'AdmissionDate': datetime.date(2022, 9, 11), 'DischargeDate': datetime.date(2022, 12, 21)}, {'AdmissionID': 36, 'PatientID': 834, 'AdmissionDate': datetime.date(2022, 8, 2), 'DischargeDate': datetime.date(2022, 12, 11)}, {'AdmissionID': 37, 'PatientID': 378, 'AdmissionDate': datetime.date(2023, 3, 13), 'DischargeDate': datetime.date(2023, 1, 9)}, {'AdmissionID': 38, 'PatientID': 586, 'AdmissionDate': datetime.date(2021, 6, 25), 'DischargeDate': datetime.date(2022, 10, 20)}, {'AdmissionID': 39, 'PatientID': 782, 'AdmissionDate': datetime.date(2022, 6, 12), 'DischargeDate': datetime.date(2023, 2, 20)}, {'AdmissionID': 40, 'PatientID': 742, 'AdmissionDate': datetime.date(2022, 6, 15), 'DischargeDate': datetime.date(2022, 11, 24)}, {'AdmissionID': 41, 'PatientID': 896, 'AdmissionDate': datetime.date(2022, 4, 20), 'DischargeDate': datetime.date(2022, 6, 13)}, {'AdmissionID': 42, 'PatientID': 173, 'AdmissionDate': datetime.date(2021, 7, 2), 'DischargeDate': datetime.date(2022, 7, 24)}, {'AdmissionID': 43, 'PatientID': 288, 'AdmissionDate': datetime.date(2022, 10, 7), 'DischargeDate': datetime.date(2023, 3, 3)}, {'AdmissionID': 44, 'PatientID': 471, 'AdmissionDate': datetime.date(2023, 4, 4), 'DischargeDate': datetime.date(2022, 5, 20)}, {'AdmissionID': 45, 'PatientID': 713, 'AdmissionDate': datetime.date(2023, 2, 3), 'DischargeDate': datetime.date(2022, 5, 30)}, {'AdmissionID': 46, 'PatientID': 63, 'AdmissionDate': datetime.date(2022, 4, 26), 'DischargeDate': datetime.date(2023, 4, 9)}, {'AdmissionID': 47, 'PatientID': 552, 'AdmissionDate': datetime.date(2023, 2, 22), 'DischargeDate': datetime.date(2022, 9, 3)}, {'AdmissionID': 48, 'PatientID': 696, 'AdmissionDate': datetime.date(2023, 1, 7), 'DischargeDate': datetime.date(2022, 7, 9)}, {'AdmissionID': 49, 'PatientID': 575, 'AdmissionDate': datetime.date(2022, 4, 10), 'DischargeDate': datetime.date(2022, 8, 23)}, {'AdmissionID': 50, 'PatientID': 906, 'AdmissionDate': datetime.date(2021, 9, 8), 'DischargeDate': datetime.date(2022, 10, 12)}, {'AdmissionID': 51, 'PatientID': 464, 'AdmissionDate': datetime.date(2022, 11, 24), 'DischargeDate': datetime.date(2023, 3, 13)}, {'AdmissionID': 52, 'PatientID': 741, 'AdmissionDate': datetime.date(2021, 7, 6), 'DischargeDate': datetime.date(2023, 2, 7)}, {'AdmissionID': 53, 'PatientID': 972, 'AdmissionDate': datetime.date(2021, 7, 29), 'DischargeDate': datetime.date(2022, 7, 2)}, {'AdmissionID': 54, 'PatientID': 340, 'AdmissionDate': datetime.date(2021, 9, 18), 'DischargeDate': datetime.date(2022, 9, 28)}, {'AdmissionID': 55, 'PatientID': 1013, 'AdmissionDate': datetime.date(2022, 8, 2), 'DischargeDate': datetime.date(2022, 9, 7)}, {'AdmissionID': 56, 'PatientID': 436, 'AdmissionDate': datetime.date(2021, 9, 19), 'DischargeDate': datetime.date(2022, 7, 16)}, {'AdmissionID': 57, 'PatientID': 617, 'AdmissionDate': datetime.date(2021, 7, 6), 'DischargeDate': datetime.date(2022, 6, 13)}, {'AdmissionID': 58, 'PatientID': 458, 'AdmissionDate': datetime.date(2022, 4, 18), 'DischargeDate': datetime.date(2023, 1, 30)}, {'AdmissionID': 59, 'PatientID': 737, 'AdmissionDate': datetime.date(2022, 11, 6), 'DischargeDate': datetime.date(2022, 8, 10)}, {'AdmissionID': 60, 'PatientID': 780, 'AdmissionDate': datetime.date(2023, 4, 15), 'DischargeDate': datetime.date(2023, 4, ...
# Rooms_data: [{'RoomID': 30, 'RoomNumber': 695, 'RoomType': 'Shared', 'DepartmentID': 269}, {'RoomID': 31, 'RoomNumber': 443, 'RoomType': 'Shared', 'DepartmentID': 805}, {'RoomID': 32, 'RoomNumber': 798, 'RoomType': 'Shared', 'DepartmentID': 198}, {'RoomID': 33, 'RoomNumber': 140, 'RoomType': 'Private', 'DepartmentID': 784}, {'RoomID': 34, 'RoomNumber': 892, 'RoomType': 'Private', 'DepartmentID': 356}, {'RoomID': 35, 'RoomNumber': 738, 'RoomType': 'Shared', 'DepartmentID': 841}, {'RoomID': 36, 'RoomNumber': 644, 'RoomType': 'Shared', 'DepartmentID': 731}, {'RoomID': 37, 'RoomNumber': 551, 'RoomType': 'Shared', 'DepartmentID': 923}, {'RoomID': 38, 'RoomNumber': 959, 'RoomType': 'Shared', 'DepartmentID': 675}, {'RoomID': 39, 'RoomNumber': 254, 'RoomType': 'Shared', 'DepartmentID': 41}, {'RoomID': 40, 'RoomNumber': 342, 'RoomType': 'Shared', 'DepartmentID': 663}, {'RoomID': 41, 'RoomNumber': 313, 'RoomType': 'Shared', 'DepartmentID': 511}, {'RoomID': 42, 'RoomNumber': 171, 'RoomType': 'Private', 'DepartmentID': 967}, {'RoomID': 43, 'RoomNumber': 456, 'RoomType': 'Shared', 'DepartmentID': 869}, {'RoomID': 44, 'RoomNumber': 661, 'RoomType': 'Private', 'DepartmentID': 377}, {'RoomID': 45, 'RoomNumber': 669, 'RoomType': 'Shared', 'DepartmentID': 853}, {'RoomID': 46, 'RoomNumber': 262, 'RoomType': 'Shared', 'DepartmentID': 127}, {'RoomID': 47, 'RoomNumber': 491, 'RoomType': 'Shared', 'DepartmentID': 627}, {'RoomID': 48, 'RoomNumber': 643, 'RoomType': 'Shared', 'DepartmentID': 356}, {'RoomID': 49, 'RoomNumber': 475, 'RoomType': 'Shared', 'DepartmentID': 819}, {'RoomID': 50, 'RoomNumber': 253, 'RoomType': 'Private', 'DepartmentID': 930}, {'RoomID': 51, 'RoomNumber': 666, 'RoomType': 'Shared', 'DepartmentID': 303}, {'RoomID': 52, 'RoomNumber': 982, 'RoomType': 'Shared', 'DepartmentID': 328}, {'RoomID': 53, 'RoomNumber': 195, 'RoomType': 'Private', 'DepartmentID': 359}, {'RoomID': 54, 'RoomNumber': 185, 'RoomType': 'Private', 'DepartmentID': 315}, {'RoomID': 55, 'RoomNumber': 572, 'RoomType': 'Private', 'DepartmentID': 585}, {'RoomID': 56, 'RoomNumber': 826, 'RoomType': 'Shared', 'DepartmentID': 441}, {'RoomID': 57, 'RoomNumber': 586, 'RoomType': 'Shared', 'DepartmentID': 910}, {'RoomID': 58, 'RoomNumber': 945, 'RoomType': 'Private', 'DepartmentID': 247}, {'RoomID': 59, 'RoomNumber': 907, 'RoomType': 'Private', 'DepartmentID': 804}, {'RoomID': 60, 'RoomNumber': 514, 'RoomType': 'Shared', 'DepartmentID': 822}, {'RoomID': 61, 'RoomNumber': 712, 'RoomType': 'Shared', 'DepartmentID': 48}, {'RoomID': 62, 'RoomNumber': 652, 'RoomType': 'Private', 'DepartmentID': 695}, {'RoomID': 63, 'RoomNumber': 285, 'RoomType': 'Shared', 'DepartmentID': 466}, {'RoomID': 64, 'RoomNumber': 872, 'RoomType': 'Shared', 'DepartmentID': 465}, {'RoomID': 65, 'RoomNumber': 824, 'RoomType': 'Private', 'DepartmentID': 402}, {'RoomID': 66, 'RoomNumber': 687, 'RoomType': 'Shared', 'DepartmentID': 655}, {'RoomID': 67, 'RoomNumber': 456, 'RoomType': 'Shared', 'DepartmentID': 1014}, {'RoomID': 68, 'RoomNumber': 423, 'RoomType': 'Private', 'DepartmentID': 684}, {'RoomID': 69, 'RoomNumber': 211, 'RoomType': 'Shared', 'DepartmentID': 721}, {'RoomID': 70, 'RoomNumber': 606, 'RoomType': 'Private', 'DepartmentID': 823}, {'RoomID': 71, 'RoomNumber': 940, 'RoomType': 'Private', 'DepartmentID': 90}, {'RoomID': 72, 'RoomNumber': 331, 'RoomType': 'Shared', 'DepartmentID': 504}, {'RoomID': 73, 'RoomNumber': 379, 'RoomType': 'Private', 'DepartmentID': 170}, {'RoomID': 74, 'RoomNumber': 199, 'RoomType': 'Shared', 'DepartmentID': 374}, {'RoomID': 75, 'RoomNumber': 296, 'RoomType': 'Private', 'DepartmentID': 881}, {'RoomID': 76, 'RoomNumber': 268, 'RoomType': 'Shared', 'DepartmentID': 170}, {'RoomID': 77, 'RoomNumber': 706, 'RoomType': 'Shared', 'DepartmentID': 473}, {'RoomID': 78, 'RoomNumber': 666, 'RoomType': 'Shared', 'DepartmentID': 922}, {'RoomID': 79, 'RoomNumber': 996, 'RoomType': 'Private', 'DepartmentID': 310}, {'RoomID': 80, 'RoomNumber': 373, 'RoomType': 'Shared', 'DepartmentID': ...
# Beds_data: [{'BedID': 30, 'RoomID': 893, 'BedNumber': 4}, {'BedID': 31, 'RoomID': 230, 'BedNumber': 3}, {'BedID': 32, 'RoomID': 252, 'BedNumber': 6}, {'BedID': 33, 'RoomID': 512, 'BedNumber': 10}, {'BedID': 34, 'RoomID': 175, 'BedNumber': 6}, {'BedID': 35, 'RoomID': 697, 'BedNumber': 10}, {'BedID': 36, 'RoomID': 315, 'BedNumber': 9}, {'BedID': 37, 'RoomID': 385, 'BedNumber': 2}, {'BedID': 38, 'RoomID': 166, 'BedNumber': 6}, {'BedID': 39, 'RoomID': 207, 'BedNumber': 3}, {'BedID': 40, 'RoomID': 751, 'BedNumber': 9}, {'BedID': 41, 'RoomID': 613, 'BedNumber': 9}, {'BedID': 42, 'RoomID': 543, 'BedNumber': 3}, {'BedID': 43, 'RoomID': 731, 'BedNumber': 7}, {'BedID': 44, 'RoomID': 816, 'BedNumber': 1}, {'BedID': 45, 'RoomID': 54, 'BedNumber': 6}, {'BedID': 46, 'RoomID': 220, 'BedNumber': 8}, {'BedID': 47, 'RoomID': 819, 'BedNumber': 5}, {'BedID': 48, 'RoomID': 695, 'BedNumber': 5}, {'BedID': 49, 'RoomID': 796, 'BedNumber': 8}, {'BedID': 50, 'RoomID': 115, 'BedNumber': 10}, {'BedID': 51, 'RoomID': 58, 'BedNumber': 5}, {'BedID': 52, 'RoomID': 100, 'BedNumber': 9}, {'BedID': 53, 'RoomID': 925, 'BedNumber': 6}, {'BedID': 54, 'RoomID': 884, 'BedNumber': 2}, {'BedID': 55, 'RoomID': 238, 'BedNumber': 4}, {'BedID': 56, 'RoomID': 135, 'BedNumber': 4}, {'BedID': 57, 'RoomID': 319, 'BedNumber': 4}, {'BedID': 58, 'RoomID': 937, 'BedNumber': 8}, {'BedID': 59, 'RoomID': 253, 'BedNumber': 5}, {'BedID': 60, 'RoomID': 253, 'BedNumber': 1}, {'BedID': 61, 'RoomID': 455, 'BedNumber': 2}, {'BedID': 62, 'RoomID': 885, 'BedNumber': 5}, {'BedID': 63, 'RoomID': 455, 'BedNumber': 5}, {'BedID': 64, 'RoomID': 301, 'BedNumber': 9}, {'BedID': 65, 'RoomID': 190, 'BedNumber': 6}, {'BedID': 66, 'RoomID': 45, 'BedNumber': 3}, {'BedID': 67, 'RoomID': 639, 'BedNumber': 8}, {'BedID': 68, 'RoomID': 780, 'BedNumber': 2}, {'BedID': 69, 'RoomID': 596, 'BedNumber': 2}, {'BedID': 70, 'RoomID': 284, 'BedNumber': 3}, {'BedID': 71, 'RoomID': 152, 'BedNumber': 4}, {'BedID': 72, 'RoomID': 860, 'BedNumber': 5}, {'BedID': 73, 'RoomID': 89, 'BedNumber': 10}, {'BedID': 74, 'RoomID': 766, 'BedNumber': 8}, {'BedID': 75, 'RoomID': 937, 'BedNumber': 10}, {'BedID': 76, 'RoomID': 37, 'BedNumber': 3}, {'BedID': 77, 'RoomID': 129, 'BedNumber': 7}, {'BedID': 78, 'RoomID': 342, 'BedNumber': 4}, {'BedID': 79, 'RoomID': 468, 'BedNumber': 3}, {'BedID': 80, 'RoomID': 612, 'BedNumber': 3}, {'BedID': 81, 'RoomID': 732, 'BedNumber': 1}, {'BedID': 82, 'RoomID': 241, 'BedNumber': 6}, {'BedID': 83, 'RoomID': 225, 'BedNumber': 1}, {'BedID': 84, 'RoomID': 805, 'BedNumber': 5}, {'BedID': 85, 'RoomID': 382, 'BedNumber': 10}, {'BedID': 86, 'RoomID': 390, 'BedNumber': 9}, {'BedID': 87, 'RoomID': 98, 'BedNumber': 2}, {'BedID': 88, 'RoomID': 122, 'BedNumber': 5}, {'BedID': 89, 'RoomID': 570, 'BedNumber': 2}, {'BedID': 90, 'RoomID': 874, 'BedNumber': 10}, {'BedID': 91, 'RoomID': 853, 'BedNumber': 4}, {'BedID': 92, 'RoomID': 620, 'BedNumber': 3}, {'BedID': 93, 'RoomID': 180, 'BedNumber': 2}, {'BedID': 94, 'RoomID': 678, 'BedNumber': 6}, {'BedID': 95, 'RoomID': 263, 'BedNumber': 2}, {'BedID': 96, 'RoomID': 170, 'BedNumber': 8}, {'BedID': 97, 'RoomID': 591, 'BedNumber': 5}, {'BedID': 98, 'RoomID': 848, 'BedNumber': 2}, {'BedID': 99, 'RoomID': 217, 'BedNumber': 7}, {'BedID': 100, 'RoomID': 906, 'BedNumber': 2}, {'BedID': 101, 'RoomID': 175, 'BedNumber': 4}, {'BedID': 102, 'RoomID': 101, 'BedNumber': 10}, {'BedID': 103, 'RoomID': 229, 'BedNumber': 6}, {'BedID': 104, 'RoomID': 287, 'BedNumber': 5}, {'BedID': 105, 'RoomID': 1028, 'BedNumber': 7}, {'BedID': 106, 'RoomID': 1023, 'BedNumber': 3}, {'BedID': 107, 'RoomID': 354, 'BedNumber': 4}, {'BedID': 108, 'RoomID': 827, 'BedNumber': 2}, {'BedID': 109, 'RoomID': 392, 'BedNumber': 8}, {'BedID': 110, 'RoomID': 475, 'BedNumber': 3}, {'BedID': 111, 'RoomID': 249, 'BedNumber': 5}, {'BedID': 112, 'RoomID': 893, 'BedNumber': 6}, {'BedID': 113, 'RoomID': 126, 'BedNumber': 5}, {'BedID': 114, 'RoomID': 524, 'BedNumber': 3}, {'BedID': 115, 'RoomID': 328, 'BedNumber': 6}, {'BedID': 11 ...
# Medications_data: [{'MedicationID': 30, 'MedicationName': 'set', 'MedicationDescription': 'At lot conference report over.'}, {'MedicationID': 31, 'MedicationName': 'morning', 'MedicationDescription': 'Business color order commercial note development begin.'}, {'MedicationID': 32, 'MedicationName': 'note', 'MedicationDescription': 'Rich about it me less like tax.'}, {'MedicationID': 33, 'MedicationName': 'card', 'MedicationDescription': 'Party child religious vote kind available main worry.'}, {'MedicationID': 34, 'MedicationName': 'section', 'MedicationDescription': 'Gas air sound protect information.'}, {'MedicationID': 35, 'MedicationName': 'little', 'MedicationDescription': 'Always clearly chair generation within affect a.'}, {'MedicationID': 36, 'MedicationName': 'now', 'MedicationDescription': 'Employee smile theory level simple fear player.'}, {'MedicationID': 37, 'MedicationName': 'resource', 'MedicationDescription': 'Return guy program quickly Mr any.'}, {'MedicationID': 38, 'MedicationName': 'public', 'MedicationDescription': 'None ability let today reason several not.'}, {'MedicationID': 39, 'MedicationName': 'prevent', 'MedicationDescription': 'Respond include per heart man perhaps interesting describe.'}, {'MedicationID': 40, 'MedicationName': 'girl', 'MedicationDescription': 'Far even fill expect.'}, {'MedicationID': 41, 'MedicationName': 'budget', 'MedicationDescription': 'Nearly wall bring occur attorney still work one.'}, {'MedicationID': 42, 'MedicationName': 'wear', 'MedicationDescription': 'Role protect piece doctor leg sense seat season.'}, {'MedicationID': 43, 'MedicationName': 'consumer', 'MedicationDescription': 'Right sound song focus.'}, {'MedicationID': 44, 'MedicationName': 'rich', 'MedicationDescription': 'Design least detail speak suddenly bank.'}, {'MedicationID': 45, 'MedicationName': 'anyone', 'MedicationDescription': 'Later build talk myself.'}, {'MedicationID': 46, 'MedicationName': 'media', 'MedicationDescription': 'Clearly per sit now nearly no.'}, {'MedicationID': 47, 'MedicationName': 'operation', 'MedicationDescription': 'Along particular have level conference.'}, {'MedicationID': 48, 'MedicationName': 'control', 'MedicationDescription': 'Son child administration discuss now voice.'}, {'MedicationID': 49, 'MedicationName': 'step', 'MedicationDescription': 'Adult life somebody always research fact beat.'}, {'MedicationID': 50, 'MedicationName': 'little', 'MedicationDescription': 'Next who letter exactly federal range election.'}, {'MedicationID': 51, 'MedicationName': 'music', 'MedicationDescription': 'Law notice next key power.'}, {'MedicationID': 52, 'MedicationName': 'rise', 'MedicationDescription': 'Purpose bag able camera.'}, {'MedicationID': 53, 'MedicationName': 'attorney', 'MedicationDescription': 'Get reason decision anything hit charge listen responsibility.'}, {'MedicationID': 54, 'MedicationName': 'last', 'MedicationDescription': 'Scientist much policy.'}, {'MedicationID': 55, 'MedicationName': 'role', 'MedicationDescription': 'Attorney per thank cover.'}, {'MedicationID': 56, 'MedicationName': 'activity', 'MedicationDescription': 'Southern nice skin.'}, {'MedicationID': 57, 'MedicationName': 'accept', 'MedicationDescription': 'Remain tree grow bit.'}, {'MedicationID': 58, 'MedicationName': 'wait', 'MedicationDescription': 'Allow blood affect walk kind technology music.'}, {'MedicationID': 59, 'MedicationName': 'free', 'MedicationDescription': 'Company less increase.'}, {'MedicationID': 60, 'MedicationName': 'operation', 'MedicationDescription': 'Family vote summer operation rise operation.'}, {'MedicationID': 61, 'MedicationName': 'maybe', 'MedicationDescription': 'Nor figure partner country you challenge real.'}, {'MedicationID': 62, 'MedicationName': 'charge', 'MedicationDescription': 'Job away southern happy close office others.'}, {'MedicationID': 63, 'MedicationName': 'environment', 'MedicationDescription': 'Stop design no finally carry movie.'}, {'MedicationID': 64, 'Med ...
# Prescriptions_data: [{'PrescriptionID': 30, 'PatientID': 249, 'DoctorID': 389, 'MedicationID': 143, 'PrescriptionDate': datetime.date(2023, 1, 18), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 31, 'PatientID': 909, 'DoctorID': 73, 'MedicationID': 929, 'PrescriptionDate': datetime.date(2022, 9, 6), 'Dosage': '1 capsule'}, {'PrescriptionID': 32, 'PatientID': 435, 'DoctorID': 663, 'MedicationID': 781, 'PrescriptionDate': datetime.date(2022, 11, 6), 'Dosage': '2 tablets'}, {'PrescriptionID': 33, 'PatientID': 543, 'DoctorID': 56, 'MedicationID': 282, 'PrescriptionDate': datetime.date(2022, 5, 17), 'Dosage': '1 tablet'}, {'PrescriptionID': 34, 'PatientID': 821, 'DoctorID': 682, 'MedicationID': 355, 'PrescriptionDate': datetime.date(2022, 9, 25), 'Dosage': '1 tablet'}, {'PrescriptionID': 35, 'PatientID': 701, 'DoctorID': 808, 'MedicationID': 431, 'PrescriptionDate': datetime.date(2023, 1, 30), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 36, 'PatientID': 862, 'DoctorID': 411, 'MedicationID': 948, 'PrescriptionDate': datetime.date(2022, 5, 20), 'Dosage': '1 capsule'}, {'PrescriptionID': 37, 'PatientID': 293, 'DoctorID': 567, 'MedicationID': 676, 'PrescriptionDate': datetime.date(2023, 5, 5), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 38, 'PatientID': 997, 'DoctorID': 838, 'MedicationID': 984, 'PrescriptionDate': datetime.date(2023, 5, 3), 'Dosage': '1 tablet'}, {'PrescriptionID': 39, 'PatientID': 400, 'DoctorID': 518, 'MedicationID': 935, 'PrescriptionDate': datetime.date(2023, 3, 22), 'Dosage': '2 tablets'}, {'PrescriptionID': 40, 'PatientID': 461, 'DoctorID': 1024, 'MedicationID': 206, 'PrescriptionDate': datetime.date(2023, 3, 22), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 41, 'PatientID': 716, 'DoctorID': 718, 'MedicationID': 580, 'PrescriptionDate': datetime.date(2022, 11, 24), 'Dosage': '1 tablet'}, {'PrescriptionID': 42, 'PatientID': 258, 'DoctorID': 540, 'MedicationID': 340, 'PrescriptionDate': datetime.date(2022, 9, 24), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 43, 'PatientID': 317, 'DoctorID': 796, 'MedicationID': 946, 'PrescriptionDate': datetime.date(2023, 4, 16), 'Dosage': '1 capsule'}, {'PrescriptionID': 44, 'PatientID': 261, 'DoctorID': 66, 'MedicationID': 219, 'PrescriptionDate': datetime.date(2022, 9, 8), 'Dosage': '1 tablet'}, {'PrescriptionID': 45, 'PatientID': 966, 'DoctorID': 446, 'MedicationID': 674, 'PrescriptionDate': datetime.date(2023, 4, 1), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 46, 'PatientID': 442, 'DoctorID': 114, 'MedicationID': 400, 'PrescriptionDate': datetime.date(2022, 10, 20), 'Dosage': '1 tablet'}, {'PrescriptionID': 47, 'PatientID': 217, 'DoctorID': 258, 'MedicationID': 700, 'PrescriptionDate': datetime.date(2022, 10, 24), 'Dosage': '1 tablet'}, {'PrescriptionID': 48, 'PatientID': 238, 'DoctorID': 643, 'MedicationID': 579, 'PrescriptionDate': datetime.date(2022, 9, 26), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 49, 'PatientID': 595, 'DoctorID': 437, 'MedicationID': 191, 'PrescriptionDate': datetime.date(2022, 8, 7), 'Dosage': '1 tablet'}, {'PrescriptionID': 50, 'PatientID': 265, 'DoctorID': 537, 'MedicationID': 983, 'PrescriptionDate': datetime.date(2023, 4, 19), 'Dosage': '2 tablets'}, {'PrescriptionID': 51, 'PatientID': 66, 'DoctorID': 96, 'MedicationID': 810, 'PrescriptionDate': datetime.date(2022, 7, 23), 'Dosage': '1 capsule'}, {'PrescriptionID': 52, 'PatientID': 782, 'DoctorID': 552, 'MedicationID': 305, 'PrescriptionDate': datetime.date(2022, 7, 13), 'Dosage': '1 tablet'}, {'PrescriptionID': 53, 'PatientID': 392, 'DoctorID': 499, 'MedicationID': 459, 'PrescriptionDate': datetime.date(2022, 9, 30), 'Dosage': '1 capsule'}, {'PrescriptionID': 54, 'PatientID': 386, 'DoctorID': 361, 'MedicationID': 690, 'PrescriptionDate': datetime.date(2022, 6, 7), 'Dosage': '1 tablet'}, {'PrescriptionID': 55, 'PatientID': 130, 'DoctorID': 31, 'MedicationID': 600, 'PrescriptionDate': datetime.date(2022, 7, 14), 'Dosage': '1 teaspoon'}, {'PrescriptionID': 56, 'PatientID': 612, 'DoctorID': 978, 'Medic ...
# Billing_data: [{'BillID': 30, 'PatientID': 711, 'BillDate': datetime.date(2023, 1, 25), 'TotalCost': 331.31}, {'BillID': 31, 'PatientID': 624, 'BillDate': datetime.date(2022, 11, 10), 'TotalCost': 973.83}, {'BillID': 32, 'PatientID': 642, 'BillDate': datetime.date(2022, 7, 27), 'TotalCost': 864.32}, {'BillID': 33, 'PatientID': 514, 'BillDate': datetime.date(2022, 12, 24), 'TotalCost': 460.67}, {'BillID': 34, 'PatientID': 58, 'BillDate': datetime.date(2022, 12, 12), 'TotalCost': 790.93}, {'BillID': 35, 'PatientID': 75, 'BillDate': datetime.date(2023, 2, 9), 'TotalCost': 632.41}, {'BillID': 36, 'PatientID': 1004, 'BillDate': datetime.date(2022, 12, 9), 'TotalCost': 254.64}, {'BillID': 37, 'PatientID': 141, 'BillDate': datetime.date(2023, 3, 24), 'TotalCost': 537.54}, {'BillID': 38, 'PatientID': 661, 'BillDate': datetime.date(2022, 10, 14), 'TotalCost': 586.19}, {'BillID': 39, 'PatientID': 103, 'BillDate': datetime.date(2022, 11, 10), 'TotalCost': 884.4}, {'BillID': 40, 'PatientID': 724, 'BillDate': datetime.date(2022, 12, 22), 'TotalCost': 375.04}, {'BillID': 41, 'PatientID': 259, 'BillDate': datetime.date(2022, 9, 20), 'TotalCost': 728.35}, {'BillID': 42, 'PatientID': 766, 'BillDate': datetime.date(2022, 7, 14), 'TotalCost': 481.17}, {'BillID': 43, 'PatientID': 301, 'BillDate': datetime.date(2022, 11, 28), 'TotalCost': 976.97}, {'BillID': 44, 'PatientID': 383, 'BillDate': datetime.date(2023, 1, 29), 'TotalCost': 899.75}, {'BillID': 45, 'PatientID': 664, 'BillDate': datetime.date(2023, 2, 2), 'TotalCost': 358.39}, {'BillID': 46, 'PatientID': 75, 'BillDate': datetime.date(2023, 3, 30), 'TotalCost': 178.27}, {'BillID': 47, 'PatientID': 304, 'BillDate': datetime.date(2022, 6, 2), 'TotalCost': 993.06}, {'BillID': 48, 'PatientID': 154, 'BillDate': datetime.date(2022, 10, 6), 'TotalCost': 198.97}, {'BillID': 49, 'PatientID': 785, 'BillDate': datetime.date(2022, 7, 30), 'TotalCost': 169.28}, {'BillID': 50, 'PatientID': 949, 'BillDate': datetime.date(2023, 3, 5), 'TotalCost': 984.3}, {'BillID': 51, 'PatientID': 781, 'BillDate': datetime.date(2022, 7, 23), 'TotalCost': 621.7}, {'BillID': 52, 'PatientID': 604, 'BillDate': datetime.date(2023, 5, 9), 'TotalCost': 370.77}, {'BillID': 53, 'PatientID': 263, 'BillDate': datetime.date(2023, 4, 4), 'TotalCost': 743.7}, {'BillID': 54, 'PatientID': 114, 'BillDate': datetime.date(2022, 9, 17), 'TotalCost': 774.51}, {'BillID': 55, 'PatientID': 822, 'BillDate': datetime.date(2023, 3, 16), 'TotalCost': 407.09}, {'BillID': 56, 'PatientID': 1010, 'BillDate': datetime.date(2022, 7, 26), 'TotalCost': 716.54}, {'BillID': 57, 'PatientID': 260, 'BillDate': datetime.date(2022, 10, 29), 'TotalCost': 168.15}, {'BillID': 58, 'PatientID': 319, 'BillDate': datetime.date(2022, 5, 14), 'TotalCost': 464.68}, {'BillID': 59, 'PatientID': 592, 'BillDate': datetime.date(2023, 5, 6), 'TotalCost': 156.37}, {'BillID': 60, 'PatientID': 98, 'BillDate': datetime.date(2023, 1, 27), 'TotalCost': 221.35}, {'BillID': 61, 'PatientID': 823, 'BillDate': datetime.date(2023, 1, 12), 'TotalCost': 411.12}, {'BillID': 62, 'PatientID': 163, 'BillDate': datetime.date(2022, 7, 8), 'TotalCost': 342.67}, {'BillID': 63, 'PatientID': 674, 'BillDate': datetime.date(2023, 5, 7), 'TotalCost': 537.35}, {'BillID': 64, 'PatientID': 941, 'BillDate': datetime.date(2023, 2, 21), 'TotalCost': 422.59}, {'BillID': 65, 'PatientID': 232, 'BillDate': datetime.date(2022, 11, 30), 'TotalCost': 563.1}, {'BillID': 66, 'PatientID': 915, 'BillDate': datetime.date(2023, 1, 30), 'TotalCost': 884.84}, {'BillID': 67, 'PatientID': 30, 'BillDate': datetime.date(2023, 3, 11), 'TotalCost': 597.28}, {'BillID': 68, 'PatientID': 593, 'BillDate': datetime.date(2022, 6, 6), 'TotalCost': 709.0}, {'BillID': 69, 'PatientID': 189, 'BillDate': datetime.date(2022, 8, 9), 'TotalCost': 272.19}, {'BillID': 70, 'PatientID': 307, 'BillDate': datetime.date(2023, 4, 4), 'TotalCost': 869.05}, {'BillID': 71, 'PatientID': 865, 'BillDate': datetime.date(2023, 3, 15), 'TotalCost': 434.37}, {'BillI ...
# Payments_data: [{'PaymentID': 30, 'PatientID': 706, 'PaymentDate': datetime.date(2022, 7, 14), 'PaymentAmount': 404.28}, {'PaymentID': 31, 'PatientID': 691, 'PaymentDate': datetime.date(2022, 10, 12), 'PaymentAmount': 174.15}, {'PaymentID': 32, 'PatientID': 289, 'PaymentDate': datetime.date(2023, 2, 27), 'PaymentAmount': 171.95}, {'PaymentID': 33, 'PatientID': 525, 'PaymentDate': datetime.date(2022, 12, 31), 'PaymentAmount': 163.42}, {'PaymentID': 34, 'PatientID': 972, 'PaymentDate': datetime.date(2022, 11, 1), 'PaymentAmount': 298.61}, {'PaymentID': 35, 'PatientID': 660, 'PaymentDate': datetime.date(2022, 7, 5), 'PaymentAmount': 279.78}, {'PaymentID': 36, 'PatientID': 537, 'PaymentDate': datetime.date(2023, 3, 22), 'PaymentAmount': 356.74}, {'PaymentID': 37, 'PatientID': 821, 'PaymentDate': datetime.date(2022, 6, 21), 'PaymentAmount': 208.33}, {'PaymentID': 38, 'PatientID': 902, 'PaymentDate': datetime.date(2022, 7, 31), 'PaymentAmount': 141.21}, {'PaymentID': 39, 'PatientID': 572, 'PaymentDate': datetime.date(2022, 7, 22), 'PaymentAmount': 154.72}, {'PaymentID': 40, 'PatientID': 276, 'PaymentDate': datetime.date(2022, 11, 10), 'PaymentAmount': 161.98}, {'PaymentID': 41, 'PatientID': 708, 'PaymentDate': datetime.date(2023, 2, 26), 'PaymentAmount': 455.68}, {'PaymentID': 42, 'PatientID': 685, 'PaymentDate': datetime.date(2022, 12, 18), 'PaymentAmount': 304.27}, {'PaymentID': 43, 'PatientID': 435, 'PaymentDate': datetime.date(2022, 12, 5), 'PaymentAmount': 131.09}, {'PaymentID': 44, 'PatientID': 945, 'PaymentDate': datetime.date(2023, 4, 27), 'PaymentAmount': 333.56}, {'PaymentID': 45, 'PatientID': 575, 'PaymentDate': datetime.date(2023, 5, 2), 'PaymentAmount': 481.3}, {'PaymentID': 46, 'PatientID': 627, 'PaymentDate': datetime.date(2023, 4, 27), 'PaymentAmount': 70.01}, {'PaymentID': 47, 'PatientID': 377, 'PaymentDate': datetime.date(2022, 8, 25), 'PaymentAmount': 238.84}, {'PaymentID': 48, 'PatientID': 219, 'PaymentDate': datetime.date(2023, 3, 22), 'PaymentAmount': 184.03}, {'PaymentID': 49, 'PatientID': 462, 'PaymentDate': datetime.date(2023, 1, 9), 'PaymentAmount': 363.62}, {'PaymentID': 50, 'PatientID': 536, 'PaymentDate': datetime.date(2023, 2, 2), 'PaymentAmount': 202.91}, {'PaymentID': 51, 'PatientID': 486, 'PaymentDate': datetime.date(2022, 9, 10), 'PaymentAmount': 420.37}, {'PaymentID': 52, 'PatientID': 229, 'PaymentDate': datetime.date(2022, 7, 21), 'PaymentAmount': 79.23}, {'PaymentID': 53, 'PatientID': 86, 'PaymentDate': datetime.date(2022, 10, 6), 'PaymentAmount': 323.57}, {'PaymentID': 54, 'PatientID': 770, 'PaymentDate': datetime.date(2022, 10, 10), 'PaymentAmount': 251.85}, {'PaymentID': 55, 'PatientID': 209, 'PaymentDate': datetime.date(2022, 9, 11), 'PaymentAmount': 238.73}, {'PaymentID': 56, 'PatientID': 425, 'PaymentDate': datetime.date(2023, 4, 6), 'PaymentAmount': 227.73}, {'PaymentID': 57, 'PatientID': 146, 'PaymentDate': datetime.date(2022, 9, 30), 'PaymentAmount': 460.67}, {'PaymentID': 58, 'PatientID': 350, 'PaymentDate': datetime.date(2022, 10, 4), 'PaymentAmount': 302.72}, {'PaymentID': 59, 'PatientID': 808, 'PaymentDate': datetime.date(2023, 4, 28), 'PaymentAmount': 274.71}, {'PaymentID': 60, 'PatientID': 572, 'PaymentDate': datetime.date(2022, 9, 21), 'PaymentAmount': 458.59}, {'PaymentID': 61, 'PatientID': 126, 'PaymentDate': datetime.date(2023, 1, 30), 'PaymentAmount': 334.17}, {'PaymentID': 62, 'PatientID': 697, 'PaymentDate': datetime.date(2022, 8, 17), 'PaymentAmount': 287.7}, {'PaymentID': 63, 'PatientID': 620, 'PaymentDate': datetime.date(2022, 10, 22), 'PaymentAmount': 139.93}, {'PaymentID': 64, 'PatientID': 283, 'PaymentDate': datetime.date(2023, 1, 4), 'PaymentAmount': 70.59}, {'PaymentID': 65, 'PatientID': 348, 'PaymentDate': datetime.date(2023, 1, 19), 'PaymentAmount': 82.34}, {'PaymentID': 66, 'PatientID': 606, 'PaymentDate': datetime.date(2022, 6, 12), 'PaymentAmount': 275.95}, {'PaymentID': 67, 'PatientID': 642, 'PaymentDate': datetime.date(2023, 3, 8), 'PaymentAmount': 287.23}, {' ...

# %%
import psycopg2

# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="hospital_database",
    user="postgres",
    password="czy490603"
)
cur = conn.cursor()

# Define the SQL INSERT statements for each table
patients_insert_query = "INSERT INTO Patients (PatientID, FirstName, LastName, Gender, DateOfBirth, Address, PhoneNumber) VALUES (%s, %s, %s, %s, %s, %s, %s)"
doctors_insert_query = "INSERT INTO Doctors (DoctorID, FirstName, LastName, Gender, DateOfBirth, Address, PhoneNumber, Specialization) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
appointments_insert_query = "INSERT INTO Appointments (AppointmentID, PatientID, DoctorID, AppointmentDate, AppointmentTime) VALUES (%s, %s, %s, %s, %s)"
medical_records_insert_query = "INSERT INTO MedicalRecords (RecordID, PatientID, DoctorID, RecordDate, Diagnosis, Treatment) VALUES (%s, %s, %s, %s, %s, %s)"
departments_insert_query = "INSERT INTO Departments (DepartmentID, DepartmentName) VALUES (%s, %s)"
staff_insert_query = "INSERT INTO Staff (StaffID, DepartmentID, FirstName, LastName, Gender, DateOfBirth, Address, PhoneNumber) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
admissions_insert_query = "INSERT INTO Admissions (AdmissionID, PatientID, AdmissionDate, DischargeDate) VALUES (%s, %s, %s, %s)"
rooms_insert_query = "INSERT INTO Rooms (RoomID, RoomNumber, RoomType, DepartmentID) VALUES (%s, %s, %s, %s)"
beds_insert_query = "INSERT INTO Beds (BedID, RoomID, BedNumber) VALUES (%s, %s, %s)"
medications_insert_query = "INSERT INTO Medications (MedicationID, MedicationName, MedicationDescription) VALUES (%s, %s, %s)"
prescriptions_insert_query = "INSERT INTO Prescriptions (PrescriptionID, PatientID, DoctorID, MedicationID, PrescriptionDate, Dosage) VALUES (%s, %s, %s, %s, %s, %s)"
billing_insert_query = "INSERT INTO Billing (BillID, PatientID, BillDate, TotalCost) VALUES (%s, %s, %s, %s)"
payments_insert_query = "INSERT INTO Payments (PaymentID, PatientID, PaymentDate, PaymentAmount) VALUES (%s, %s, %s, %s)"

# Insert the generated data into the database
cur.executemany(patients_insert_query, [(p['PatientID'], p['FirstName'], p['LastName'], p['Gender'], p['DateOfBirth'], p['Address'], p['PhoneNumber']) for p in patients_data])
cur.executemany(doctors_insert_query, [(d['DoctorID'], d['FirstName'], d['LastName'], d['Gender'], d['DateOfBirth'], d['Address'], d['PhoneNumber'], d['Specialization']) for d in doctors_data])
cur.executemany(appointments_insert_query, [(a['AppointmentID'], a['PatientID'], a['DoctorID'], a['AppointmentDate'], a['AppointmentTime']) for a in appointments_data])
cur.executemany(medical_records_insert_query, [(m['RecordID'], m['PatientID'], m['DoctorID'], m['RecordDate'], m['Diagnosis'], m['Treatment']) for m in medical_records_data])
cur.executemany(departments_insert_query, [(d['DepartmentID'], d['DepartmentName']) for d in departments_data])
cur.executemany(staff_insert_query, [(s['StaffID'], s['DepartmentID'], s['FirstName'], s['LastName'], s['Gender'], s['DateOfBirth'], s['Address'], s['PhoneNumber']) for s in staff_data])
cur.executemany(admissions_insert_query, [(a['AdmissionID'], a['PatientID'], a['AdmissionDate'], a['DischargeDate']) for a in admissions_data])
cur.executemany(rooms_insert_query, [(r['RoomID'], r['RoomNumber'], r['RoomType'], r['DepartmentID']) for r in rooms_data])
cur.executemany(beds_insert_query, [(b['BedID'], b['RoomID'], b['BedNumber']) for b in beds_data])
cur.executemany(medications_insert_query, [(m['MedicationID'], m['MedicationName'], m['MedicationDescription']) for m in medications_data])
cur.executemany(prescriptions_insert_query, [(p['PrescriptionID'], p['PatientID'], p['DoctorID'], p['MedicationID'], p['PrescriptionDate'], p['Dosage']) for p in prescriptions_data])
cur.executemany(billing_insert_query, [(b['BillID'], b['PatientID'], b['BillDate'], b['TotalCost']) for b in billing_data])
cur.executemany(payments_insert_query, [(p['PaymentID'], p['PatientID'], p['PaymentDate'], p['PaymentAmount']) for p in payments_data])

# Commit the changes and close the cursor and connection
conn.commit()
cur.close()
conn.close()

print("Data insertion completed.")
# Out:
# Data insertion completed.

# %%
conn.close()
